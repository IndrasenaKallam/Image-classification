# %%
# libraries

import pandas as pd
import numpy as np
import tensorflow as tf
import keras 
from tensorflow.keras import models,layers
from keras.layers import Conv2D, MaxPool2D, Dense, Dropout, Flatten
from keras.models import Sequential
from tensorflow.keras import optimizers

def data_load_labels(data, labels):
    data_df = pd.read_csv(data, header=None)
    X = data_df.values.reshape((-1, 28, 28, 4)).clip(0, 255).astype(np.uint8)
    labels_df = pd.read_csv(labels, header=None)
    y = labels_df.values.getfield(dtype=np.int8)
    return X, y

X_train, y_train = data_load_labels(data='C:/Users/19405/Desktop/Capstone 2/X_train_sat6.csv',
                                    labels='C:/Users/19405/Desktop/Capstone 2/y_train_sat6.csv')

X_test, y_test = data_load_labels(data='C:/Users/19405/Desktop/Capstone 2/X_test_sat6.csv',
                                    labels='C:/Users/19405/Desktop/Capstone 2/y_test_sat6.csv')


print("Training data shape ", X_train.shape, y_train.shape)
print("Testing data shape ", X_test.shape, y_test.shape)
# Out:
# Training data shape  (324000, 28, 28, 4) (324000, 6)
# Testing data shape  (81000, 28, 28, 4) (81000, 6)

# %%
# Set up an image generator to feed image tiles to the model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_generator=train_datagen.flow(X_train[:280000],y_train[:280000],batch_size=512) #puts 280,000 images in train
val_generator=val_datagen.flow(X_train[280000:],y_train[280000:],batch_size=512) #puts 64,800 records in val

# %%
# Base model
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28,28, 4))) #  RGB+IR images.
# model.add(layers.Conv2D(32, (3, 3),activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())  #collapse to 1D
model.add(layers.Dropout(0.5)) #added to reduce overfitting
model.add(layers.Dense(512,activation='relu')) #reduce after flatten
model.add(layers.Dense(6,activation='softmax')) #final 6-way classification, predict class

# %%
# model summary
print(model.summary())
# early stopping
from keras.callbacks import EarlyStopping
early_stop_mon=EarlyStopping(patience=3)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit(train_generator,epochs=30, verbose=1, validation_data=val_generator, callbacks=[early_stop_mon])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        1184
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               819712
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 3078
# =================================================================
# Total params: 842,470
# Trainable params: 842,470
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 547 steps, validate for 86 steps
# Epoch 1/30
# 547/547 [==============================] - 192s 351ms/step - loss: 0.1436 - accuracy: 0.9453 - val_loss: 0.0704 - val_accuracy: 0.9754
# Epoch 2/30
# 547/547 [==============================] - 182s 333ms/step - loss: 0.0624 - accuracy: 0.9783 - val_loss: 0.0505 - val_accuracy: 0.9821
# Epoch 3/30
# 547/547 [==============================] - 190s 348ms/step - loss: 0.0500 - accuracy: 0.9823 - val_loss: 0.0406 - val_accuracy: 0.9857
# Epoch 4/30
# 547/547 [==============================] - 207s 379ms/step - loss: 0.0444 - accuracy: 0.9843 - val_loss: 0.0480 - val_accuracy: 0.9817
# Epoch 5/30
# 547/547 [==============================] - 211s 386ms/step - loss: 0.0402 - accuracy: 0.9858 - val_loss: 0.0354 - val_accuracy: 0.9880
# Epoch 6/30
# 547/547 [==============================] - 220s 403ms/step - loss: 0.0380 - accuracy: 0.9867 - val_loss: 0.0309 - val_accuracy: 0.9895
# Epoch 7/30
# 547/547 [==============================] - 229s 419ms/step - loss: 0.0345 - accuracy: 0.9880 - val_loss: 0.0282 - val_accuracy: 0.9905
# Epoch 8/30
# 547/547 [==============================] - 213s 390ms/step - loss: 0.0337 - accuracy: 0.9882 - val_loss: 0.0283 - val_accuracy: 0.9904
# Epoch 9/30
# 547/547 [==============================] - 209s 382ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 0.0301 - val_accuracy: 0.9896
# Epoch 10/30
# 547/547 [==============================] - 213s 389ms/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 0.0279 - val_accuracy: 0.9906
# Epoch 11/30
# 547/547 [==============================] - 195s 356ms/step - loss: 0.0278 - accuracy: 0.9904 - val_loss: 0.0276 - val_accuracy: 0.9909
# Epoch 12/30
# 547/547 [==============================] - 189s 346ms/step - loss: 0.0270 - accuracy: 0.9905 - val_loss: 0.0334 - val_accuracy: 0.9887
# Epoch 13/30
# 547/547 [==============================] - 196s 358ms/step - loss: 0.0254 - accuracy: 0.9910 - val_loss: 0.0167 - val_accuracy: 0.9948
# Epoch 14/30
# 547/547 [==============================] - 205s 375ms/step - loss: 0.0223 - accuracy: 0.9923 - val_loss: 0.0184 - val_accuracy: 0.9938
# Epoch 15/30
# 547/547 [==============================] - 207s 378ms/step - loss: 0.0221 - accuracy: 0.9922 - val_loss: 0.0183 - val_accuracy: 0.9943
# Epoch 16/30
# 547/547 [==============================] - 198s 362ms/step - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.0172 - val_accuracy: 0.9941

# %%
model.save_weights('deepsat6-30epochs-weights.h5')

# %%
hist_df=pd.DataFrame.from_dict(model.history.history)
hist_df.to_csv('history.csv')

# %%
model.history.history
# Out:
# {'loss': [0.143563827758176,
#   0.062393186363152095,
#   0.05003423378297261,
#   0.0443766374877521,
#   0.04019948969057628,
#   0.0379828800201416,
#   0.03444989027466093,
#   0.03373520906823022,
#   0.029527750515937805,
#   0.027476604704345976,
#   0.027818831394399914,
#   0.026980932783229012,
#   0.025380525614534105,
#   0.022323114899226598,
#   0.022102756762078832,
#   0.022148261735269],
#  'accuracy': [0.9452643,
#   0.9783286,
#   0.9823464,
#   0.98429286,
#   0.9857857,
#   0.9867393,
#   0.98798215,
#   0.98824286,
#   0.98990715,
#   0.9904607,
#   0.9904107,
#   0.99050355,
#   0.9910464,
#   0.9922929,
#   0.99222857,
#   0.9922357],
#  'val_loss': [0.0704285487705885,
#   0.05046937051554059,
#   0.0405834732620522,
#   0.04804214692219745,
#   0.03536718886692163,
#   0.030859622887747233,
#   0.028186877821247246,
#   0.028270401872781126,
#   0.030066148497077616,
#   0.02788856600108015,
#   0.027571057608394428,
#   0.03343653252218352,
#   0.01670007932346401,
#   0.018425491194478994,
#   0.018317060317670882,
#   0.017171692752907444],
#  'val_accuracy': [0.9754091,
#   0.9820682,
#   0.98572725,
#   0.98170453,
#   0.98804545,
#   0.98952276,
#   0.99052274,
#   0.99038637,
#   0.9895682,
#   0.99056816,
#   0.9908636,
#   0.9886591,
#   0.99479544,
#   0.99379545,
#   0.9942727,
#   0.9940682]}

# %%
# Plot model fitting
import matplotlib.pyplot as plt
# adapted from Deep Learning With Python (Chollet)
h=model.history.history
epochs = range(len(h['accuracy']))
fig,ax=plt.subplots(1,2,figsize=(13,5))
ax[0].plot(epochs, h['accuracy'], 'r', label='Training')
ax[0].plot(epochs, h['val_accuracy'], 'b', label='Validation')
ax[0].set_title('Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].legend()
ax[1].plot(epochs, h['loss'], 'r', label='Training')
ax[1].plot(epochs, h['val_loss'], 'b', label='Validation')
ax[1].set_title('Loss')
ax[1].set_xlabel('Epochs')
ax[1].legend()
plt.suptitle('Evaluation of Model Fit Over {} Epochs'.format(len(h['accuracy'])));

# %% [markdown]
# # Evaluate on Held out set

# %%
# Look at predictions on held-out data
testX_rescaled=X_test/255
predy=model.predict(testX_rescaled)

# %%
categories ={0: 'building', 1: 'barren land',2: 'trees',3: 'grassland',4: 'road',5: 'water'}

# %%
#get pd Series of predicted and actual categories for test dataset
testycat=pd.DataFrame(y_test).idxmax(axis=1).map(categories) #actual
testycat_pred=pd.DataFrame(predy).idxmax(axis=1).map(categories) #pred

# %%
#Plot results
pred_df=testycat_pred.value_counts()
act_df=testycat.value_counts()
fig,ax=plt.subplots(figsize=(10,5))
ind=np.arange(6)
width=0.35
pred=ax.bar(ind+width,pred_df.values,width=width,label='predicted')
act=ax.bar(ind,act_df.values,width=width,label='actual')
ax.set_xticks(ind+width/2)
ax.set_xticklabels(pred_df.index)
ax.legend()
ax.set_title('Comparison of predicted and actual categories on test dataset');

# %%
#get prediction errors
compare_df=pd.concat([testycat,testycat_pred],axis=1)
compare_df.columns=['actual','predicted']
compare_df=compare_df.assign(mismatch=compare_df.actual!=compare_df.predicted)
compare_df.loc[compare_df.mismatch].head()
# Out:
#            actual    predicted  mismatch
# 92    barren land    grassland      True
# 120     grassland  barren land      True
# 325          road     building      True
# 938     grassland  barren land      True
# 1309  barren land    grassland      True

# %%
compare_df['mismatch'].value_counts()
# Out:
# False    80564
# True       436
# Name: mismatch, dtype: int64

# %%
#accuracy on test dataset
print('Overall accuracy on test dataset: {0:.3f}'.format(1-(compare_df.mismatch.sum()/compare_df.mismatch.count())))
# Out:
# Overall accuracy on test dataset: 0.995

# %%
# Look at confusion matrix, classification report
from sklearn.metrics import classification_report,confusion_matrix
print('Classification Report:')
print(classification_report(testycat,testycat_pred))
#print('Confusion Matrix:')
#print(confusion_matrix(testycat,testycat_pred))
#print('\nNumber of Correct Classifications:')
correct=compare_df.loc[~compare_df.mismatch].groupby(['actual','predicted']).count()
#correct.columns=['Correct']
#print(correct) #check order of entries in confusion matrix
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#  barren land       0.99      0.99      0.99     18367
#     building       0.99      1.00      0.99      3714
#    grassland       0.98      0.99      0.98     12596
#         road       1.00      0.98      0.99      2070
#        trees       1.00      1.00      1.00     14185
#        water       1.00      1.00      1.00     30068
#
#     accuracy                           0.99     81000
#    macro avg       0.99      0.99      0.99     81000
# weighted avg       0.99      0.99      0.99     81000

# %%
#plot confusion matrix as heatmap
import seaborn as sns
cm=confusion_matrix(testycat,testycat_pred)
labels=correct.index.get_level_values(0).values
ax=sns.heatmap(cm,xticklabels=labels,yticklabels=labels,annot=True,fmt='d',cmap="YlGnBu",cbar=False)
ax.set_title('Confusion Matrix')
ax.set_ylabel('Actual')
ax.set_xlabel('Predicted');

# %%
import rasterio as rio
from rasterio.windows import Window
import os

# %%
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
  
# Read Images 
img = mpimg.imread('download.jpg') 
  
# Output Images 
plt.imshow(img)

# %%
import rasterio as rio
from rasterio.windows import Window

from PIL import Image
indra = Image.open('download.jpg')

"""
import os
imgdir=r'.'
files=os.listdir(imgdir)
# psfile=os.path.join(imgdir,files[11])
psfile = os.path('download.jpg')
print(psfile)
with rio.open(psfile) as src:
psimg=Image.read(window=Window(0,0,1500,1500))


psimg

"""
# !pip install cv2
import cv2
cv2.namedWindow("output", cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
im = cv2.imread("download.jpg")                        # Read image
imS = cv2.resize(im, (960, 540))                    # Resize image
cv2.imshow("output", imS)                            # Show image
cv2.waitKey(0)
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-55-be878a88634b> in <module>
#      20 """
#      21 get_ipython().system('pip install cv2')
# ---> 22 import cv2
#      23 cv2.namedWindow("output", cv2.WINDOW_NORMAL)        # Create window with freedom of dimensions
#      24 im = cv2.imread("download.jpg")                        # Read image
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
plt.imshow(np.rollaxis(psimg,axis=0,start=3)[:,:,:3])

# %%
#function to make tiles from the image
def make_naip_tiles(bigimg,tilesize):
  bigimg=np.rollaxis(bigimg,axis=0,start=3)#redim raw image
  width,height,bands=bigimg.shape
  ntile_y=np.int(np.floor(width/tilesize))
  ntile_x=np.int(np.floor(height/tilesize))
  ntiles=ntile_x*ntile_y
  startix=0
  reshaped=np.empty((ntiles,tilesize,tilesize,bands))
  for xi in range(ntile_x):
    xl=tilesize*xi
    xr=xl+tilesize
    for yi in range(ntile_y):
      yl=tilesize*yi
      yr=yl+tilesize
      reshaped[startix]=bigimg[xl:xr,yl:yr,:]
      startix+=1
  return reshaped

# %%
#reshape the source image
rs=make_naip_tiles(psimg,28)
rs.shape
# Out:
# (2809, 28, 28, 4)

# %%
#input to CNN and predict classes
newimg=rs/255
pred_new_y=model.predict(rs)

# %%
#get pd Series of predicted categories of unseen data
newycat=pd.DataFrame(pred_new_y).idxmax(axis=1).map(categories) #actual
newycat
# Out:
# 0       grassland
# 1           trees
# 2       grassland
# 3       grassland
# 4       grassland
#           ...
# 2804    grassland
# 2805    grassland
# 2806    grassland
# 2807    grassland
# 2808    grassland
# Length: 2809, dtype: object

# %%
#inspect a few tile predictions
fig,axs=plt.subplots(1,5,figsize=(20,10))
ixs=[700,1000,1250,1500,176]
for i in range(5):
  axs[i].imshow(rs[ixs[i],:,:,:3].astype(int))
  axs[i].set_title(newycat.iloc[ixs[i]])

# %%
#reassemble classified image - is it what we expect?
catix=pd.DataFrame(pred_new_y).idxmax(axis=1)
catix.value_counts()
# Out:
# 3    1691
# 1     845
# 2     197
# 0      76
# dtype: int64

# %%
n_xtiles=np.sqrt(rs.shape[0])
n_ytiles=n_xtiles
tile_size=28

# %%
#use pandas to reshape and pivot results (convert this workflow to numpy)
newdf=pd.DataFrame(catix,columns=['Class'])
newdf['ix1']=newdf.index
newdf['row']=newdf.ix1.apply(lambda x:np.floor(x/n_xtiles))
newdf['col']=newdf.ix1.apply(lambda x:np.mod(x,n_xtiles))
pivimg=newdf.pivot('row','col','Class').to_numpy()

# %%
#look at results
from matplotlib.colors import ListedColormap
cmap=ListedColormap(['#c93420','#faf4e6','g','#9c855a','k','b'])#custom colormap
fig,axs=plt.subplots(1,2,figsize=(20,10))
im=axs[0].imshow(pivimg,cmap=cmap)
cb=fig.colorbar(im, ax=axs[0])
cb.set_ticks(np.linspace(0.5,4.5,6))
cb.ax.set_yticklabels([categories[i] for i in range(6)])

axs[1].imshow(np.rollaxis(psimg,axis=0,start=3)[:,:,:3])
axs[0].set_title('Classified Image')
axs[1].set_title('Original Image');
